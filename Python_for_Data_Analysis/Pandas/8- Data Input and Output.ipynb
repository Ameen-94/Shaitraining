# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('test.csv', encoding='windows-1256') 
df
# Out:
#       التسلسل                                        اسم الجمعية  \
# 0         NaN                                                NaN
# 1         1.0  الجمعية التعاونية لمستخدمي المياه حوض (5) الزر...
# 2         2.0  جمعية مستخدمي المياه مضخه (14) التعاونية الزراعية
# 3         3.0  جمعية الباقورة لمستخدمي المياه حوض (3+4) التعا...
# 4         4.0             جمعية عين السليخات التعاونية الزراعية
# ...       ...                                                ...
# 1454   1454.0          جمعية السيق البارد التعاونية السياحية م.غ
# 1455   1455.0               جمعية ابناء اذرح السياحية التعاونية
# 1456   1456.0               جمعية جبل مسعوده التعاونية السياحية
# 1457   1457.0                 جمعية الجلف التعاونية السياحية م.غ
# 1458   1458.0                 جمعية الطيبة الجنوبية السياحية م.غ
#
#       الرقم الوطني  نوع الجمعية  عدد الأعضاء المحافظة
# 0               NaN         NaN          NaN       NaN
# 1      5.201131e+08      زراعيه         81.0      اربد
# ...

# %%
df = df.drop(index=0).reset_index()
df
# Out:
#       index  التسلسل                                        اسم الجمعية  \
# 0         1      1.0  الجمعية التعاونية لمستخدمي المياه حوض (5) الزر...
# 1         2      2.0  جمعية مستخدمي المياه مضخه (14) التعاونية الزراعية
# 2         3      3.0  جمعية الباقورة لمستخدمي المياه حوض (3+4) التعا...
# 3         4      4.0             جمعية عين السليخات التعاونية الزراعية
# 4         5      5.0  جمعية مزارعي طبقة فحل التعاونية الزراعية المضخ...
# ...     ...      ...                                                ...
# 1453   1454   1454.0          جمعية السيق البارد التعاونية السياحية م.غ
# 1454   1455   1455.0               جمعية ابناء اذرح السياحية التعاونية
# 1455   1456   1456.0               جمعية جبل مسعوده التعاونية السياحية
# 1456   1457   1457.0                 جمعية الجلف التعاونية السياحية م.غ
# 1457   1458   1458.0                 جمعية الطيبة الجنوبية السياحية م.غ
#
#       الرقم الوطني  نوع الجمعية  عدد الأعضاء المحافظة
# ...

# %%
df.isnull().sum()
# Out:
# index            0
# التسلسل          0
# اسم الجمعية      0
# الرقم الوطني     0
# نوع الجمعية      0
# عدد الأعضاء      1
# المحافظة         0
# dtype: int64

# %%
df[df['عدد الأعضاء'].isnull()]
# Out:
#      index  التسلسل            اسم الجمعية  الرقم الوطني  نوع الجمعية  \
# 884    885    885.0  جمعية الشهد التعاونية    820072745.0      سياحية
#
#      عدد الأعضاء المحافظة
# 884          NaN     عجلون

# %%
df.drop(columns=['index'], inplace=True)
df
# Out:
#       التسلسل                                        اسم الجمعية  \
# 0         1.0  الجمعية التعاونية لمستخدمي المياه حوض (5) الزر...
# 1         2.0  جمعية مستخدمي المياه مضخه (14) التعاونية الزراعية
# 2         3.0  جمعية الباقورة لمستخدمي المياه حوض (3+4) التعا...
# 3         4.0             جمعية عين السليخات التعاونية الزراعية
# 4         5.0  جمعية مزارعي طبقة فحل التعاونية الزراعية المضخ...
# ...       ...                                                ...
# 1453   1454.0          جمعية السيق البارد التعاونية السياحية م.غ
# 1454   1455.0               جمعية ابناء اذرح السياحية التعاونية
# 1455   1456.0               جمعية جبل مسعوده التعاونية السياحية
# 1456   1457.0                 جمعية الجلف التعاونية السياحية م.غ
# 1457   1458.0                 جمعية الطيبة الجنوبية السياحية م.غ
#
#       الرقم الوطني  نوع الجمعية  عدد الأعضاء المحافظة
# 0      5.201131e+08      زراعيه         81.0      اربد
# 1      5.201130e+08      زراعية        135.0      اربد
# ...

# %%
df['التسلسل'].astype(int)
df
# Out:
#       التسلسل                                        اسم الجمعية  \
# 0         1.0  الجمعية التعاونية لمستخدمي المياه حوض (5) الزر...
# 1         2.0  جمعية مستخدمي المياه مضخه (14) التعاونية الزراعية
# 2         3.0  جمعية الباقورة لمستخدمي المياه حوض (3+4) التعا...
# 3         4.0             جمعية عين السليخات التعاونية الزراعية
# 4         5.0  جمعية مزارعي طبقة فحل التعاونية الزراعية المضخ...
# ...       ...                                                ...
# 1453   1454.0          جمعية السيق البارد التعاونية السياحية م.غ
# 1454   1455.0               جمعية ابناء اذرح السياحية التعاونية
# 1455   1456.0               جمعية جبل مسعوده التعاونية السياحية
# 1456   1457.0                 جمعية الجلف التعاونية السياحية م.غ
# 1457   1458.0                 جمعية الطيبة الجنوبية السياحية م.غ
#
#       الرقم الوطني  نوع الجمعية  عدد الأعضاء المحافظة
# 0      5.201131e+08      زراعيه         81.0      اربد
# 1      5.201130e+08      زراعية        135.0      اربد
# ...

# %%
df.drop(index=884, inplace=True)

# %%
df.isnull().sum()
# Out:
# التسلسل          0
# اسم الجمعية      0
# الرقم الوطني     0
# نوع الجمعية      0
# عدد الأعضاء      0
# المحافظة         0
# dtype: int64

# %%
df['عدد الأعضاء'].mean()
# Out:
# np.float64(88.36582017844887)

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('test-fixed.csv', encoding='utf-8')

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
excel_df = pd.read_excel('جداول_القطاع_العام_الكلي_2015.xlsx', sheet_name='توزريع العاملين')

# %%
excel_df
# Out:
#      توزيع العاملين في نهاية السنة حسب الجنسية والصنف لسنة 2015 Unnamed: 1  \
# 0                                     اصناف العاملين             العراقيون
# 1              رئيس الشركة والمدراء العامون ومعاونيهم                   18
# 2   العاملون في الامور الادارية والذاتية والاحصاء ...                 9558
# 3                       العاملون في الحسابات والتدقيق                 3561
# 4                  العاملون في المشتريات والاستيرادات                  975
# 5                              العاملون في المبيــعات                10055
# 6                               العاملون في المخــازن                 3601
# 7                        العاملون في الشعب الفنيــــة                 6302
# 8          العاملون في شعبة الصيانة والتصليح والانتاج                 8311
# 9                              العاملون في الخـدمــات                 6204
# 10                                            المجموع                48585
# ...

# %%
excel_df.drop(columns=['Unnamed: 4','Unnamed: 5','Unnamed: 6'], inplace=True)

# %%
excel_df.rename(
    columns={
        "2015 توزيع العاملين في نهاية السنة حسب الجنسية والصنف لسنة ": "اصناف العاملين",
        "Unnamed: 1": "العراقيون",
        "Unnamed: 2": "العرب",
        "Unnamed: 3": "المجموع",
    },
    inplace=True,
)

# %%
excel_df.drop(index=0, inplace=True)

# %%
excel_df.dropna(how='all', inplace=True)

# %%
excel_df
# Out:
#      توزيع العاملين في نهاية السنة حسب الجنسية والصنف لسنة 2015 العراقيون  \
# 1              رئيس الشركة والمدراء العامون ومعاونيهم                  18
# 2   العاملون في الامور الادارية والذاتية والاحصاء ...                9558
# 3                       العاملون في الحسابات والتدقيق                3561
# 4                  العاملون في المشتريات والاستيرادات                 975
# 5                              العاملون في المبيــعات               10055
# 6                               العاملون في المخــازن                3601
# 7                        العاملون في الشعب الفنيــــة                6302
# 8          العاملون في شعبة الصيانة والتصليح والانتاج                8311
# 9                              العاملون في الخـدمــات                6204
# 10                                            المجموع               48585
# 12   توزيع العاملين في نهاية السنة حسب الجنس والصن...                 NaN
# 14                                    اصناف العاملين                ذكور
# ...

# %%
df_1 = excel_df.iloc[11:,:].copy()
excel_df.drop(index=df_1.index,inplace=True)
excel_df
# Out:
#      توزيع العاملين في نهاية السنة حسب الجنسية والصنف لسنة 2015 العراقيون  \
# 1              رئيس الشركة والمدراء العامون ومعاونيهم                  18
# 2   العاملون في الامور الادارية والذاتية والاحصاء ...                9558
# 3                       العاملون في الحسابات والتدقيق                3561
# 4                  العاملون في المشتريات والاستيرادات                 975
# 5                              العاملون في المبيــعات               10055
# 6                               العاملون في المخــازن                3601
# 7                        العاملون في الشعب الفنيــــة                6302
# 8          العاملون في شعبة الصيانة والتصليح والانتاج                8311
# 9                              العاملون في الخـدمــات                6204
# 10                                            المجموع               48585
# 12   توزيع العاملين في نهاية السنة حسب الجنس والصن...                 NaN
#
#    العرب المجموع
# 1      0      18
# 2      6    9564
# 3      4    3565
# ...

# %%
excel_df.drop(index=12,inplace=True)

# %%
excel_df
# Out:
#      توزيع العاملين في نهاية السنة حسب الجنسية والصنف لسنة 2015 العراقيون  \
# 1              رئيس الشركة والمدراء العامون ومعاونيهم                  18
# 2   العاملون في الامور الادارية والذاتية والاحصاء ...                9558
# 3                       العاملون في الحسابات والتدقيق                3561
# 4                  العاملون في المشتريات والاستيرادات                 975
# 5                              العاملون في المبيــعات               10055
# 6                               العاملون في المخــازن                3601
# 7                        العاملون في الشعب الفنيــــة                6302
# 8          العاملون في شعبة الصيانة والتصليح والانتاج                8311
# 9                              العاملون في الخـدمــات                6204
# 10                                            المجموع               48585
#
#    العرب المجموع
# 1      0      18
# 2      6    9564
# 3      4    3565
# 4      2     977
# 5      4   10059
# 6      5    3606
# 7      4    6306
# ...

# %% [markdown]
# ### Excel Output

# %%
excel_df.to_excel('Excel_Fixed.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('https://www.fdic.gov/bank-failures/failed-bank-list?combine=&items_per_page=10') #Task using this link
print(df)
# Out:
# [                               Bank Name           City         State   Cert  \
# 0           The Santa Anna National Bank     Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank        Chicago      Illinois  28611
# 2     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank       Sac City          Iowa   8758
# 5               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 6                    First Republic Bank  San Francisco    California  59017
# 7                         Signature Bank       New York      New York  57053
# 8                    Silicon Valley Bank    Santa Clara    California  24735
# 9                      Almena State Bank         Almena        Kansas  15426
#
#                  Acquiring Institution      Closing Date  Fund  Sort ascending
# ...

# %%
print(len(df))
# Out:
# 1

# %%
print(len(df[0]))
# Out:
# 10

# %%
df[0]
# Out:
#                                Bank Name           City         State   Cert  \
# 0           The Santa Anna National Bank     Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank        Chicago      Illinois  28611
# 2     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank       Sac City          Iowa   8758
# 5               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 6                    First Republic Bank  San Francisco    California  59017
# 7                         Signature Bank       New York      New York  57053
# 8                    Silicon Valley Bank    Santa Clara    California  24735
# 9                      Almena State Bank         Almena        Kansas  15426
#
#                  Acquiring Institution      Closing Date  Fund  Sort ascending
# ...

# %% [markdown]
# ____

# %% [markdown]
# _____
# _____
# # SQL

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df1= df[0]
df1.to_sql('data', engine, index=False) # Why the error?
# Out:
# 10

# %%
sql_df = pd.read_sql('data', con=engine)

# %%
sql_df
# Out:
#                                Bank Name           City         State   Cert  \
# 0           The Santa Anna National Bank     Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank        Chicago      Illinois  28611
# 2     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank       Sac City          Iowa   8758
# 5               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 6                    First Republic Bank  San Francisco    California  59017
# 7                         Signature Bank       New York      New York  57053
# 8                    Silicon Valley Bank    Santa Clara    California  24735
# 9                      Almena State Bank         Almena        Kansas  15426
#
#                  Acquiring Institution      Closing Date  Fund  Sort ascending
# ...

# %% [markdown]
# # Great Job!
